# %% [markdown]
# # 19CSE305 ML - Pandas Exercise Questions - 23rd Aug 2023

# %% [markdown]
# ### Task 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ### Task 2. Download the dataset to your computer and unzip it.

# %% [markdown]
# ### Task 3. Use the tsv file and assign it to a dataframe called food

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r'D:\Amrita\Sem_5\Machine Learning\programs\en.openfoodfacts.org.products.tsv', delimiter='\t')
# data.head(10)
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_28600\1880962747.py:1: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv(r'D:\Amrita\Sem_5\Machine Learning\programs\en.openfoodfacts.org.products.tsv', delimiter='\t')

# %%
data.head(10)
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
# 5  16100  http://world-en.openfoodfacts.org/product/0000...
# 6  16117  http://world-en.openfoodfacts.org/product/0000...
# 7  16124  http://world-en.openfoodfacts.org/product/0000...
# 8  16193  http://world-en.openfoodfacts.org/product/0000...
# 9  16513  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
# 5             usda-ndb-import  1489055651  2017-03-09T10:34:11Z
# 6             usda-ndb-import  1489055730  2017-03-09T10:35:30Z
# 7             usda-ndb-import  1489055711  2017-03-09T10:35:11Z
# 8             usda-ndb-import  1489055651  2017-03-09T10:34:11Z
# 9             usda-ndb-import  1489055654  2017-03-09T10:34:14Z
#
#   last_modified_t last_modified_datetime                       product_name  \
# 0      1474103893   2016-09-17T09:18:13Z                 Farine de blé noir
# 1      1489069957   2017-03-09T14:32:37Z     Banana Chips Sweetened (Whole)
# 2      1489069957   2017-03-09T14:32:37Z                            Peanuts
# 3      1489055731   2017-03-09T10:35:31Z             Organic Salted Nut Mix
# 4      1489055653   2017-03-09T10:34:13Z                    Organic Polenta
# 5      1489055651   2017-03-09T10:34:11Z  Breadshop Honey Gone Nuts Granola
# 6      1489055730   2017-03-09T10:35:30Z      Organic Long Grain White Rice
# 7      1489055712   2017-03-09T10:35:12Z                     Organic Muesli
# 8      1489055651   2017-03-09T10:34:11Z       Organic Dark Chocolate Minis
# 9      1489055654   2017-03-09T10:34:14Z              Organic Sunflower Oil
#
#   generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 0          NaN      1kg  ...                         NaN
# 1          NaN      NaN  ...                         NaN
# 2          NaN      NaN  ...                         NaN
# 3          NaN      NaN  ...                         NaN
# 4          NaN      NaN  ...                         NaN
# 5          NaN      NaN  ...                         NaN
# 6          NaN      NaN  ...                         NaN
# 7          NaN      NaN  ...                         NaN
# 8          NaN      NaN  ...                         NaN
# 9          NaN      NaN  ...                         NaN
#
#   fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# 5                                  NaN                              NaN
# 6                                  NaN                              NaN
# 7                                  NaN                              NaN
# 8                                  NaN                              NaN
# 9                                  NaN                              NaN
#
#   cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0        NaN             NaN                   NaN                     NaN
# 1        NaN             NaN                   NaN                    14.0
# 2        NaN             NaN                   NaN                     0.0
# 3        NaN             NaN                   NaN                    12.0
# 4        NaN             NaN                   NaN                     NaN
# 5        NaN             NaN                   NaN                     NaN
# 6        NaN             NaN                   NaN                     NaN
# 7        NaN             NaN                   NaN                     7.0
# 8        NaN             NaN                   NaN                     NaN
# 9        NaN             NaN                   NaN                     NaN
#
#   nutrition-score-uk_100g glycemic-index_100g water-hardness_100g
# 0                     NaN                 NaN                 NaN
# 1                    14.0                 NaN                 NaN
# 2                     0.0                 NaN                 NaN
# 3                    12.0                 NaN                 NaN
# 4                     NaN                 NaN                 NaN
# 5                     NaN                 NaN                 NaN
# 6                     NaN                 NaN                 NaN
# 7                     7.0                 NaN                 NaN
# 8                     NaN                 NaN                 NaN
# 9                     NaN                 NaN                 NaN
#
# [10 rows x 163 columns]

# %% [markdown]
# ### Task 4. See the first 5 entries

# %%
data.head(5)
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1      1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2      1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3      1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4      1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#   generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 0          NaN      1kg  ...                         NaN
# 1          NaN      NaN  ...                         NaN
# 2          NaN      NaN  ...                         NaN
# 3          NaN      NaN  ...                         NaN
# 4          NaN      NaN  ...                         NaN
#
#   fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#   cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0        NaN             NaN                   NaN                     NaN
# 1        NaN             NaN                   NaN                    14.0
# 2        NaN             NaN                   NaN                     0.0
# 3        NaN             NaN                   NaN                    12.0
# 4        NaN             NaN                   NaN                     NaN
#
#   nutrition-score-uk_100g glycemic-index_100g water-hardness_100g
# 0                     NaN                 NaN                 NaN
# 1                    14.0                 NaN                 NaN
# 2                     0.0                 NaN                 NaN
# 3                    12.0                 NaN                 NaN
# 4                     NaN                 NaN                 NaN
#
# [5 rows x 163 columns]

# %% [markdown]
# ### Task 5. What is the number of observations in the dataset?

# %%
data.shape[0]
# Out:
# 356027

# %% [markdown]
# ### Task 6. What is the number of columns in the dataset?

# %%
data.shape[1]
# Out:
# 163

# %% [markdown]
# ### Task 7. Print the name of all the columns.

# %%
data.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %% [markdown]
# ### Task 8. What is the name of 105th column?

# %%
data.columns[104]
# Out:
# '-glucose_100g'

# %% [markdown]
# ### Task 9. What is the type of the observations of the 105th column?

# %%
data.dtypes[104]
# Out:
# dtype('float64')

# %% [markdown]
# ### Task 10. How is the dataset indexed?

# %%
data.index
# Out:
# RangeIndex(start=0, stop=356027, step=1)

# %% [markdown]
# ### Task 11. What is the product name of the 19th observation?

# %%
data["product_name"][18]
# Out:
# 'Lotus Organic Brown Jasmine Rice'

# %% [markdown]
# ### Task 12. How many columns in the dataset tend to have null values?

# %%
null_counts = data.isnull().sum()

print(null_counts)
# Out:
# code                           26
# url                            26
# creator                         3
# created_t                       3
# created_datetime               10
#                             ...
# carbon-footprint_100g      355749
# nutrition-score-fr_100g    101171
# nutrition-score-uk_100g    101171
# glycemic-index_100g        356027
# water-hardness_100g        356027
# Length: 163, dtype: int64

# %%
print(null_counts[null_counts > 0].count())
# Out:
# 161

# %% [markdown]
# ### Task 13. Find the number of null values present under each column?

# %%
data.isnull().sum().values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 data.isnull().sum().values()
#
# TypeError: 'numpy.ndarray' object is not callable

# %% [markdown]
# ### Task 14. Create a dictionary with keys to be column names in the dataset and values to number of null values under each column. Print the dictionary by iterating through its elements using a for loop.

# %%
d={}
null_count=data.isnull().count()
for i in range(data.shape[1]):
    d[data.columns[i]] =null_count[i]

print(d)
# Out:
# {'code': 356027, 'url': 356027, 'creator': 356027, 'created_t': 356027, 'created_datetime': 356027, 'last_modified_t': 356027, 'last_modified_datetime': 356027, 'product_name': 356027, 'generic_name': 356027, 'quantity': 356027, 'packaging': 356027, 'packaging_tags': 356027, 'brands': 356027, 'brands_tags': 356027, 'categories': 356027, 'categories_tags': 356027, 'categories_en': 356027, 'origins': 356027, 'origins_tags': 356027, 'manufacturing_places': 356027, 'manufacturing_places_tags': 356027, 'labels': 356027, 'labels_tags': 356027, 'labels_en': 356027, 'emb_codes': 356027, 'emb_codes_tags': 356027, 'first_packaging_code_geo': 356027, 'cities': 356027, 'cities_tags': 356027, 'purchase_places': 356027, 'stores': 356027, 'countries': 356027, 'countries_tags': 356027, 'countries_en': 356027, 'ingredients_text': 356027, 'allergens': 356027, 'allergens_en': 356027, 'traces': 356027, 'traces_tags': 356027, 'traces_en': 356027, 'serving_size': 356027, 'no_nutriments': 356027, 'additives_n': 356027, 'additives': 356027, 'additives_tags': 356027, 'additives_en': 356027, 'ingredients_from_palm_oil_n': 356027, 'ingredients_from_palm_oil': 356027, 'ingredients_from_palm_oil_tags': 356027, 'ingredients_that_may_be_from_palm_oil_n': 356027, 'ingredients_that_may_be_from_palm_oil': 356027, 'ingredients_that_may_be_from_palm_oil_tags': 356027, 'nutrition_grade_uk': 356027, 'nutrition_grade_fr': 356027, 'pnns_groups_1': 356027, 'pnns_groups_2': 356027, 'states': 356027, 'states_tags': 356027, 'states_en': 356027, 'main_category': 356027, 'main_category_en': 356027, 'image_url': 356027, 'image_small_url': 356027, 'energy_100g': 356027, 'energy-from-fat_100g': 356027, 'fat_100g': 356027, 'saturated-fat_100g': 356027, '-butyric-acid_100g': 356027, '-caproic-acid_100g': 356027, '-caprylic-acid_100g': 356027, '-capric-acid_100g': 356027, '-lauric-acid_100g': 356027, '-myristic-acid_100g': 356027, '-palmitic-acid_100g': 356027, '-stearic-acid_100g': 356027, '-arachidic-acid_100g': 356027, '-behenic-acid_100g': 356027, '-lignoceric-acid_100g': 356027, '-cerotic-acid_100g': 356027, '-montanic-acid_100g': 356027, '-melissic-acid_100g': 356027, 'monounsaturated-fat_100g': 356027, 'polyunsaturated-fat_100g': 356027, 'omega-3-fat_100g': 356027, '-alpha-linolenic-acid_100g': 356027, '-eicosapentaenoic-acid_100g': 356027, '-docosahexaenoic-acid_100g': 356027, 'omega-6-fat_100g': 356027, '-linoleic-acid_100g': 356027, '-arachidonic-acid_100g': 356027, '-gamma-linolenic-acid_100g': 356027, '-dihomo-gamma-linolenic-acid_100g': 356027, 'omega-9-fat_100g': 356027, '-oleic-acid_100g': 356027, '-elaidic-acid_100g': 356027, '-gondoic-acid_100g': 356027, '-mead-acid_100g': 356027, '-erucic-acid_100g': 356027, '-nervonic-acid_100g': 356027, 'trans-fat_100g': 356027, 'cholesterol_100g': 356027, 'carbohydrates_100g': 356027, 'sugars_100g': 356027, '-sucrose_100g': 356027, '-glucose_100g': 356027, '-fructose_100g': 356027, '-lactose_100g': 356027, '-maltose_100g': 356027, '-maltodextrins_100g': 356027, 'starch_100g': 356027, 'polyols_100g': 356027, 'fiber_100g': 356027, 'proteins_100g': 356027, 'casein_100g': 356027, 'serum-proteins_100g': 356027, 'nucleotides_100g': 356027, 'salt_100g': 356027, 'sodium_100g': 356027, 'alcohol_100g': 356027, 'vitamin-a_100g': 356027, 'beta-carotene_100g': 356027, 'vitamin-d_100g': 356027, 'vitamin-e_100g': 356027, 'vitamin-k_100g': 356027, 'vitamin-c_100g': 356027, 'vitamin-b1_100g': 356027, 'vitamin-b2_100g': 356027, 'vitamin-pp_100g': 356027, 'vitamin-b6_100g': 356027, 'vitamin-b9_100g': 356027, 'folates_100g': 356027, 'vitamin-b12_100g': 356027, 'biotin_100g': 356027, 'pantothenic-acid_100g': 356027, 'silica_100g': 356027, 'bicarbonate_100g': 356027, 'potassium_100g': 356027, 'chloride_100g': 356027, 'calcium_100g': 356027, 'phosphorus_100g': 356027, 'iron_100g': 356027, 'magnesium_100g': 356027, 'zinc_100g': 356027, 'copper_100g': 356027, 'manganese_100g': 356027, 'fluoride_100g': 356027, 'selenium_100g': 356027, 'chromium_100g ...

# %% [markdown]
# ### Task 15. Display the values associated with all columns from row 108 to 208?

# %%
data.iloc[108:209,:]
# Out:
#          code                                                url  \
# 108     36252  http://world-en.openfoodfacts.org/product/0000...
# 109     36269  http://world-en.openfoodfacts.org/product/0000...
# 110     36276  http://world-en.openfoodfacts.org/product/0000...
# 111     36986  http://world-en.openfoodfacts.org/product/0000...
# 112     38058  http://world-en.openfoodfacts.org/product/0000...
# ..        ...                                                ...
# 204  20043087  http://world-en.openfoodfacts.org/product/0000...
# 205  20043124  http://world-en.openfoodfacts.org/product/0000...
# 206  20043131  http://world-en.openfoodfacts.org/product/0000...
# 207  20044015  http://world-en.openfoodfacts.org/product/0000...
# 208  20044480  http://world-en.openfoodfacts.org/product/0000...
#
#              creator   created_t      created_datetime last_modified_t  \
# 108          tacinte  1422221701  2015-01-25T21:35:01Z      1494824741
# 109  usda-ndb-import  1489055651  2017-03-09T10:34:11Z      1489055651
# 110  usda-ndb-import  1489055678  2017-03-09T10:34:38Z      1489055678
# 111  usda-ndb-import  1489055649  2017-03-09T10:34:09Z      1489055649
# 112  usda-ndb-import  1489055651  2017-03-09T10:34:11Z      1489055651
# ..               ...         ...                   ...             ...
# 204  usda-ndb-import  1489135780  2017-03-10T08:49:40Z      1489135780
# 205  usda-ndb-import  1489133902  2017-03-10T08:18:22Z      1489133902
# 206  usda-ndb-import  1489133434  2017-03-10T08:10:34Z      1489133434
# 207  usda-ndb-import  1489133902  2017-03-10T08:18:22Z      1489133902
# 208  usda-ndb-import  1489133434  2017-03-10T08:10:34Z      1489133434
#
#     last_modified_datetime                             product_name  \
# 108   2017-05-15T05:05:41Z                           Lion Peanut x2
# 109   2017-03-09T10:34:11Z  Milk Chocolate Peanut Butter Malt Balls
# 110   2017-03-09T10:34:38Z              Organic Tamari Pumpkin Seed
# 111   2017-03-09T10:34:09Z                          Yogurt Pretzels
# 112   2017-03-09T10:34:11Z                     Organic Kamut Flakes
# ..                     ...                                      ...
# 204   2017-03-10T08:49:40Z                                  Biscuit
# 205   2017-03-10T08:18:22Z                    Oatmeal Raisin Cookie
# 206   2017-03-10T08:10:34Z                       Sliced Plain Bagel
# 207   2017-03-10T08:18:22Z                                    Scone
# 208   2017-03-10T08:10:34Z                   Belgian Vanilla Waffle
#
#     generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 108          NaN      NaN  ...                         NaN
# 109          NaN      NaN  ...                         NaN
# 110          NaN      NaN  ...                         NaN
# 111          NaN      NaN  ...                         NaN
# 112          NaN      NaN  ...                         NaN
# ..           ...      ...  ...                         ...
# 204          NaN      NaN  ...                         NaN
# 205          NaN      NaN  ...                         NaN
# 206          NaN      NaN  ...                         NaN
# 207          NaN      NaN  ...                         NaN
# 208          NaN      NaN  ...                         NaN
#
#     fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 108                                  NaN                              NaN
# 109                                  NaN                              NaN
# 110                                  NaN                              NaN
# 111                                  NaN                              NaN
# 112                                  NaN                              NaN
# ..                                   ...                              ...
# 204                                  NaN                              NaN
# 205                                  NaN                              NaN
# 206                                  NaN                              NaN
# 207                                  NaN                              NaN
# 208                                  NaN                              NaN
#
#     cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 108        NaN             NaN                   NaN                     NaN
# 109        NaN             NaN                   NaN                    23.0
# 110        NaN             NaN                   NaN                    15.0
# 111        NaN             NaN                   NaN                    30.0
# 112        NaN             NaN                   NaN                     NaN
# ..         ...             ...                   ...                     ...
# 204        NaN             NaN                   NaN                    18.0
# 205        NaN             NaN                   NaN                    21.0
# 206        NaN             NaN                   NaN                     2.0
# 207        NaN             NaN                   NaN                    19.0
# 208        NaN             NaN                   NaN                    25.0
#
#     nutrition-score-uk_100g glycemic-index_100g water-hardness_100g
# 108                     NaN                 NaN                 NaN
# 109                    23.0                 NaN                 NaN
# 110                    15.0                 NaN                 NaN
# 111                    30.0                 NaN                 NaN
# 112                     NaN                 NaN                 NaN
# ..                      ...                 ...                 ...
# 204                    18.0                 NaN                 NaN
# 205                    21.0                 NaN                 NaN
# 206                     2.0                 NaN                 NaN
# 207                    19.0                 NaN                 NaN
# 208                    25.0                 NaN                 NaN
#
# [101 rows x 163 columns]
